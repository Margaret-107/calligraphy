# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import _LRScheduler
import torch.utils.data as data
import torchvision
from torchvision import datasets, models, transforms
from sklearn import decomposition
from sklearn import manifold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import copy
import random
import time
from PIL import Image

# %%
test = pd.read_csv('test.csv')

# %%
train= pd.read_csv('train.csv')

# %%
char_dict=pd.Series(train.char.values,index=train.code).to_dict()

# %%
char_to_code = dict((v,k) for k,v in char_dict.items())

# %%
test['code']=test['char'].map(char_to_code)

# %%
test['label']=test['font'].map(str)+' '+test['code'].map(str)

# %%
test
# Out:
#        Unnamed: 0                    path  font char  code   label
# 0               0   char\一字\一字 楷书 欧阳询.jpg     0    一     0     0 0
# 1               1   char\一字\一字 篆书 徐三庚.jpg     4    一     0     4 0
# 2               2   char\一字\一字 草书 孙过庭.jpg     3    一     0     3 0
# 3               3    char\一字\一字 草书 张旭.jpg     3    一     0     3 0
# 4               4   char\一字\一字 草书 毛泽东.jpg     3    一     0     3 0
# ...           ...                     ...   ...  ...   ...     ...
# 13395       13395   char\龟字\龟字 草书 邓文原.jpg     3    龟  2309  3 2309
# 13396       13396    char\龟字\龟字 行书 米芾.jpg     2    龟  2309  2 2309
# 13397       13397    char\龟字\龟字 行书 苏轼.jpg     2    龟  2309  2 2309
# 13398       13398   char\龟字\龟字 行书 赵孟頫.jpg     2    龟  2309  2 2309
# 13399       13399  char\龟字\龟字 隶书 郭有道碑.jpg     1    龟  2309  1 2309
#
# [13400 rows x 6 columns]

# %%
class MyModel(nn.Module):
    def __init__(self, num_classes1, num_classes2):
        super(MyModel, self).__init__()
        self.eps = 1
        self.k=torch.FloatTensor([10])
        self.model_resnet = models.resnet50(pretrained=True)
        num_ftrs = self.model_resnet.fc.in_features
        self.model_resnet.fc = nn.Identity()
        self.fc1 = nn.Linear(num_ftrs, num_classes1)
        self.fc2 = nn.Linear(4096, num_classes2)
        self.softmax = nn.Softmax(dim=1)
        self.embed =nn.Embedding(5, 2048)

    def font_code(self,y):
        ret=torch.FloatTensor().to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
        for i, x in enumerate(y):
            result=self.embed(x)
            result=torch.reshape(result, (1,2048))
            ret=torch.cat((ret, result))
        return ret
    def predict_font_code(self,y):
        ret=torch.FloatTensor().to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
        for i, x in enumerate(y):
            num=torch.topk(x,1)[1]
            result=self.embed(num)
            result=torch.reshape(result, (1,2048))
            ret=torch.cat((ret, result))
        return ret
    def forward(self, x,y):
        x = self.model_resnet(x)
        out1 = self.fc1(x)
        p = torch.rand(1).item()
        if p < self.k / (self.k + torch.exp(self.eps / self.k)):
            font = self.font_code(y)
        else:
            font = self.predict_font_code(out1)
        #font = self.predict_font_code(out1)
        self.eps +=1
        combined = torch.cat((x.view(x.size(0), -1),font.view(font.size(0), -1)), dim=1)
        out2 = self.fc2(combined)
        return out1, out2

# %%
model = MyModel(5,2310)

# %%
def training(model, iterator, optimizer, criterion, device):
    
    epoch_loss = 0
    epoch_loss1 = 0
    epoch_loss2 = 0
    epoch_acc1 = 0
    epoch_acc2 = 0
    model.train()
    
    for x, y1,y2 in iterator:
        
        x = x.to(device)
        y1 = y1.to(device)
        y2 = y2.to(device)
        
        optimizer.zero_grad()
                
        outputs = model(x,y1)
        
        loss1 = criterion(outputs[0], y1)
        loss2 = criterion(outputs[1], y2)
        loss = loss1 + loss2 
        
        acc1 = calculate_accuracy(outputs[0], y1)
        acc2 = calculate_accuracy(outputs[1], y2)
        #gender_corrects += torch.sum(torch.topk(outputs[0], 1)[1] == torch.topk(y1, 1)[1])
        
        
        
        loss.backward()
        
        optimizer.step()
        
        epoch_loss += loss.item()
        epoch_loss1 += loss1.item()
        epoch_loss2 += loss2.item()
        epoch_acc1 += acc1.item()
        epoch_acc2 += acc2.item()
        
    return epoch_loss / len(iterator),epoch_loss1 / len(iterator),epoch_loss2 / len(iterator), epoch_acc1 / len(iterator),epoch_acc2 / len(iterator)

# %%
def evaluate(model, iterator, criterion, device):
    
    epoch_loss = 0
    epoch_loss1 = 0
    epoch_loss2 = 0
    epoch_acc1 = 0
    epoch_acc2 = 0
    model.eval()
    
    with torch.no_grad():
    
        for x, y1,y2 in iterator:
        
            x = x.to(device)
            y1 = y1.to(device)
            y2 = y2.to(device)
        
            optimizer.zero_grad()
                
            outputs = model(x,y1)
        
            loss1 = criterion(outputs[0], y1)
            loss2 = criterion(outputs[1], y2)
            loss = loss1 + loss2 
        
            acc1 = calculate_accuracy(outputs[0], y1)
            acc2 = calculate_accuracy(outputs[1], y2)
        

            epoch_loss += loss.item()
            epoch_loss1 += loss1.item()
            epoch_loss2 += loss2.item()
            epoch_acc1 += acc1.item()
            epoch_acc2 += acc2.item()
        
    return epoch_loss / len(iterator),epoch_loss1 / len(iterator),epoch_loss2 / len(iterator), epoch_acc1 / len(iterator),epoch_acc2 / len(iterator)

# %%
preprocess = transforms.Compose([
   transforms.Resize(256),
   transforms.CenterCrop(224),
   transforms.ToTensor(),
   transforms.Normalize(
       mean=[0.485, 0.456, 0.406],
       std=[0.229, 0.224, 0.225]
   )
])

# %%
class MultiTaskDataset():
    def __init__(self,df):
        self.paths = list(df.path)
        self.labels = list(df.label)

    def __len__(self): return len(self.paths)

    def __getitem__(self,idx):
        #dealing with the image
        img = Image.open(self.paths[idx]).convert('RGB')
        img = preprocess(img)


        #dealing with the labels
        labels = self.labels[idx].split(" ")
        font = torch.tensor(int(labels[0]), dtype=torch.int64)
        code = torch.tensor(int(labels[1]), dtype=torch.int64)
        
        return img.data, font, code

    def show(self,idx):
        x,y = self.__getitem__(idx)
        font,code = y
        stds = np.array([0.229, 0.224, 0.225])
        means = np.array([0.485, 0.456, 0.406])
        img = ((x.numpy().transpose((1,2,0))*stds + means)*255).astype(np.uint8)
        plt.imshow(img)
        plt.title("{} {}".format(font.item(), code.item()))

# %%
train_ds = MultiTaskDataset(train)

tr_dataloader=torch.utils.data.DataLoader(train_ds, batch_size=64, shuffle=True, num_workers=0)

# %%
test_ds = MultiTaskDataset(test)

test_dataloader=torch.utils.data.DataLoader(test_ds, batch_size=64, shuffle=True, num_workers=0)

# %%
optimizer = optim.Adam(model.parameters(), lr = 1e-3)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = nn.CrossEntropyLoss()

model = model.to(device)
criterion = criterion.to(device)

# %%
def calculate_accuracy(y_pred, y):
    top_pred = y_pred.argmax(1, keepdim = True)
    correct = top_pred.eq(y.view_as(top_pred)).sum()
    acc = correct.float() / y.shape[0]
    return acc

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
for i in range(25):
    since=time.time()
    tr_loss,font_loss,char_loss,font_acc,char_acc=training(model, tr_dataloader, optimizer, criterion, device)
    ts_loss,ts_font_loss,ts_char_loss,ts_font_acc,ts_char_acc=evaluate(model, test_dataloader, criterion, device)
    mins,secs=epoch_time(since,time.time())
    print('epochs:'+ str(i+1))
    print('min:'+str(mins)+' '+'sec:'+str(secs))
    print('training_loss:'+str(round(tr_loss, 5))+' font_loss:'+str(round(font_loss, 5))+' char_loss:'+str(round(char_loss, 5))+' font_accuracy:'+str(round(font_acc, 5))+' char_accuracy:'+str(round(char_acc, 5)))
    print('test_loss:'+str(round(ts_loss, 5))+' font_loss:'+str(round(ts_font_loss, 5))+' char_loss:'+str(round(ts_char_loss, 5))+' font_accuracy:'+str(round(ts_font_acc, 5))+' char_accuracy:'+str(round(ts_char_acc, 5)))
# Out:
# epochs:1
# min:17 sec:22
# training_loss:10.05759 font_loss:0.66202 char_loss:9.39558 font_accuracy:0.72606 char_accuracy:0.00164
# test_loss:8.57351 font_loss:0.48588 char_loss:8.08763 font_accuracy:0.8099 char_accuracy:0.00826
# epochs:2
# min:12 sec:5
# training_loss:6.79097 font_loss:0.39965 char_loss:6.39132 font_accuracy:0.83897 char_accuracy:0.04079
# test_loss:5.63754 font_loss:0.53573 char_loss:5.10181 font_accuracy:0.78909 char_accuracy:0.10022
# epochs:3
# min:10 sec:35
# training_loss:3.79024 font_loss:0.34275 char_loss:3.44749 font_accuracy:0.8631 char_accuracy:0.27275
# test_loss:3.51821 font_loss:0.4012 char_loss:3.11701 font_accuracy:0.83331 char_accuracy:0.33053
# epochs:4
# min:10 sec:38
# training_loss:2.14392 font_loss:0.29263 char_loss:1.85129 font_accuracy:0.88246 char_accuracy:0.5341
# test_loss:2.32058 font_loss:0.38885 char_loss:1.93174 font_accuracy:0.85035 char_accuracy:0.53125
# epochs:5
# min:10 sec:39
# training_loss:1.457 font_loss:0.25154 char_loss:1.20546 font_accuracy:0.89823 char_accuracy:0.66088
# test_loss:1.99185 font_loss:0.37794 char_loss:1.6139 font_accuracy:0.84975 char_accuracy:0.59301
# epochs:6
# min:10 sec:42
# training_loss:1.11511 font_loss:0.22363 char_loss:0.89147 font_accuracy:0.9106 char_accuracy:0.72736
# test_loss:1.84074 font_loss:0.32597 char_loss:1.51477 font_accuracy:0.87527 char_accuracy:0.60965
# epochs:7
# min:10 sec:43
# training_loss:0.9058 font_loss:0.19094 char_loss:0.71486 font_accuracy:0.9244 char_accuracy:0.76832
# test_loss:1.79748 font_loss:0.32337 char_loss:1.47411 font_accuracy:0.87773 char_accuracy:0.6224
# epochs:8
# min:10 sec:41
# training_loss:0.76049 font_loss:0.16218 char_loss:0.5983 font_accuracy:0.93687 char_accuracy:0.79645
# test_loss:1.73804 font_loss:0.32599 char_loss:1.41205 font_accuracy:0.88346 char_accuracy:0.63991
# epochs:9
# min:10 sec:41
# training_loss:0.65609 font_loss:0.13218 char_loss:0.52391 font_accuracy:0.95045 char_accuracy:0.81337
# test_loss:1.64171 font_loss:0.27562 char_loss:1.3661 font_accuracy:0.90089 char_accuracy:0.63991
# epochs:10
# min:10 sec:38
# training_loss:0.58504 font_loss:0.10906 char_loss:0.47598 font_accuracy:0.95913 char_accuracy:0.82539
# test_loss:1.7912 font_loss:0.41227 char_loss:1.37892 font_accuracy:0.87225 char_accuracy:0.63368
# epochs:11
# min:10 sec:42
# training_loss:0.53693 font_loss:0.09132 char_loss:0.44561 font_accuracy:0.96531 char_accuracy:0.83041
# test_loss:1.78237 font_loss:0.35793 char_loss:1.42445 font_accuracy:0.8932 char_accuracy:0.63063
# epochs:12
# min:10 sec:44
# training_loss:0.50549 font_loss:0.0801 char_loss:0.4254 font_accuracy:0.97119 char_accuracy:0.83625
# test_loss:1.68445 font_loss:0.36293 char_loss:1.32152 font_accuracy:0.89526 char_accuracy:0.64638
# epochs:13
# min:10 sec:48
# training_loss:0.46171 font_loss:0.06701 char_loss:0.3947 font_accuracy:0.97617 char_accuracy:0.84159
# test_loss:1.68622 font_loss:0.37441 char_loss:1.31181 font_accuracy:0.9005 char_accuracy:0.6439
# epochs:14
# min:10 sec:43
# training_loss:0.42055 font_loss:0.05086 char_loss:0.36969 font_accuracy:0.98292 char_accuracy:0.84715
# test_loss:1.76818 font_loss:0.41531 char_loss:1.35288 font_accuracy:0.88956 char_accuracy:0.64655
# epochs:15
# min:10 sec:42
# training_loss:0.42814 font_loss:0.05506 char_loss:0.37308 font_accuracy:0.98129 char_accuracy:0.84418
# test_loss:1.73102 font_loss:0.41336 char_loss:1.31766 font_accuracy:0.90161 char_accuracy:0.64762
# epochs:16
# min:10 sec:40
# training_loss:0.38276 font_loss:0.03691 char_loss:0.34585 font_accuracy:0.9883 char_accuracy:0.85082
# test_loss:1.6972 font_loss:0.37138 char_loss:1.32582 font_accuracy:0.906 char_accuracy:0.6475
# epochs:17
# min:10 sec:43
# training_loss:0.37799 font_loss:0.03836 char_loss:0.33963 font_accuracy:0.98711 char_accuracy:0.85004
# test_loss:1.8665 font_loss:0.52034 char_loss:1.34616 font_accuracy:0.88438 char_accuracy:0.64216
# epochs:18
# min:10 sec:50
# training_loss:0.37352 font_loss:0.03788 char_loss:0.33564 font_accuracy:0.98778 char_accuracy:0.84961
# test_loss:1.88628 font_loss:0.55198 char_loss:1.3343 font_accuracy:0.86446 char_accuracy:0.64018
# epochs:19
# min:10 sec:47
# training_loss:0.39259 font_loss:0.04643 char_loss:0.34616 font_accuracy:0.98432 char_accuracy:0.84967
# test_loss:1.83867 font_loss:0.55775 char_loss:1.28092 font_accuracy:0.87922 char_accuracy:0.65122
# epochs:20
# min:10 sec:45
# training_loss:0.35866 font_loss:0.03461 char_loss:0.32405 font_accuracy:0.98888 char_accuracy:0.85223
# test_loss:1.69714 font_loss:0.44244 char_loss:1.2547 font_accuracy:0.89683 char_accuracy:0.65464
# epochs:21
# min:10 sec:43
# training_loss:0.33549 font_loss:0.02744 char_loss:0.30805 font_accuracy:0.99169 char_accuracy:0.85595
# test_loss:1.75953 font_loss:0.45917 char_loss:1.30036 font_accuracy:0.90317 char_accuracy:0.64774
# epochs:22
# min:10 sec:47
# training_loss:0.33554 font_loss:0.02886 char_loss:0.30668 font_accuracy:0.99074 char_accuracy:0.85396
# test_loss:1.66283 font_loss:0.43613 char_loss:1.2267 font_accuracy:0.90345 char_accuracy:0.65625
# epochs:23
# min:185 sec:28
# training_loss:0.33548 font_loss:0.02914 char_loss:0.30634 font_accuracy:0.98945 char_accuracy:0.85768
# test_loss:1.66157 font_loss:0.40349 char_loss:1.25808 font_accuracy:0.90384 char_accuracy:0.64325
# epochs:24
# min:15 sec:0
# training_loss:0.33797 font_loss:0.03102 char_loss:0.30696 font_accuracy:0.98977 char_accuracy:0.85631
# test_loss:1.77089 font_loss:0.45735 char_loss:1.31353 font_accuracy:0.90203 char_accuracy:0.64142
# epochs:25
# min:10 sec:27
# training_loss:0.32275 font_loss:0.02417 char_loss:0.29858 font_accuracy:0.99219 char_accuracy:0.85437
# test_loss:1.70386 font_loss:0.46664 char_loss:1.23721 font_accuracy:0.90332 char_accuracy:0.64573

# %%
ts_loss,ts_font_loss,ts_char_loss,ts_font_acc,ts_char_acc=evaluate(model, test_dataloader, criterion, device)
print('test_loss:'+str(round(ts_loss, 5))+' font_loss:'+str(round(ts_font_loss, 5))+' char_loss:'+str(round(ts_char_loss, 5))+' font_accuracy:'+str(round(ts_font_acc, 5))+' char_accuracy:'+str(round(ts_char_acc, 5)))
# Out:
# test_loss:1.82906 font_loss:0.26717 char_loss:1.56188 font_accuracy:0.90198 char_accuracy:0.60565

# %%
tr_loss,font_loss,char_loss,font_acc,char_acc=training(model, tr_dataloader, optimizer, criterion, device)

# %%
 print('training_loss:'+str(round(tr_loss, 5))+' font_loss:'+str(round(font_loss, 5))+' char_loss:'+str(round(char_loss, 5))+' font_accuracy:'+str(round(font_acc, 5))+' char_accuracy:'+str(round(char_acc, 5)))
# Out:
# training_loss:10.06634 font_loss:0.66258 char_loss:9.40376 font_accuracy:0.72178 char_accuracy:0.00151

# %%
for i in range(3):
    since=time.time()
    tr_loss,font_loss,char_loss,font_acc,char_acc=training(model, tr_dataloader, optimizer, criterion, device)
    ts_loss,ts_font_loss,ts_char_loss,ts_font_acc,ts_char_acc=evaluate(model, test_dataloader, criterion, device)
    mins,secs=epoch_time(since,time.time())
    print('epochs:'+ str(i+1))
    print('min:'+str(mins)+' '+'sec:'+str(secs))
    print('training_loss:'+str(round(tr_loss, 5))+' font_loss:'+str(round(font_loss, 5))+' char_loss:'+str(round(char_loss, 5))+' font_accuracy:'+str(round(font_acc, 5))+' char_accuracy:'+str(round(char_acc, 5)))
    print('test_loss:'+str(round(ts_loss, 5))+' font_loss:'+str(round(ts_font_loss, 5))+' char_loss:'+str(round(ts_char_loss, 5))+' font_accuracy:'+str(round(ts_font_acc, 5))+' char_accuracy:'+str(round(ts_char_acc, 5)))
# Out:
# epochs:1
# min:10 sec:33
# training_loss:1.16303 font_loss:0.23659 char_loss:0.92645 font_accuracy:0.90523 char_accuracy:0.71775
# test_loss:1.76303 font_loss:0.28194 char_loss:1.48109 font_accuracy:0.88934 char_accuracy:0.62066
# epochs:2
# min:10 sec:46
# training_loss:0.95577 font_loss:0.20849 char_loss:0.74727 font_accuracy:0.91815 char_accuracy:0.75921
# test_loss:1.73861 font_loss:0.28723 char_loss:1.45138 font_accuracy:0.88619 char_accuracy:0.61518
# epochs:3
# min:10 sec:48
# training_loss:0.83351 font_loss:0.18967 char_loss:0.64384 font_accuracy:0.92498 char_accuracy:0.78276
# test_loss:1.77377 font_loss:0.31403 char_loss:1.45974 font_accuracy:0.88485 char_accuracy:0.61796

# %%
torch.save(model.state_dict(), "D:/caligraphy/test_model3.pth")

# %%
model.load_state_dict(torch.load("D:/caligraphy/test_model3.pth"))
# Out:
# <All keys matched successfully>

# %%
for i in range(15):
    since=time.time()
    tr_loss,font_loss,char_loss,font_acc,char_acc=training(model, tr_dataloader, optimizer, criterion, device)
    ts_loss,ts_font_loss,ts_char_loss,ts_font_acc,ts_char_acc=evaluate(model, test_dataloader, criterion, device)
    mins,secs=epoch_time(since,time.time())
    print('epochs:'+ str(i+1))
    print('min:'+str(mins)+' '+'sec:'+str(secs))
    print('training_loss:'+str(round(tr_loss, 5))+' font_loss:'+str(round(font_loss, 5))+' char_loss:'+str(round(char_loss, 5))+' font_accuracy:'+str(round(font_acc, 5))+' char_accuracy:'+str(round(char_acc, 5)))
    print('test_loss:'+str(round(ts_loss, 5))+' font_loss:'+str(round(ts_font_loss, 5))+' char_loss:'+str(round(ts_char_loss, 5))+' font_accuracy:'+str(round(ts_font_acc, 5))+' char_accuracy:'+str(round(ts_char_acc, 5)))
# Out:
# epochs:1
# min:23 sec:12
# training_loss:0.32373 font_loss:0.02539 char_loss:0.29834 font_accuracy:0.99187 char_accuracy:0.85538
# test_loss:1.74811 font_loss:0.44861 char_loss:1.2995 font_accuracy:0.90047 char_accuracy:0.64529
# epochs:2
# min:10 sec:57
# training_loss:0.32139 font_loss:0.02973 char_loss:0.29166 font_accuracy:0.99094 char_accuracy:0.85631
# test_loss:1.8117 font_loss:0.44131 char_loss:1.37039 font_accuracy:0.89764 char_accuracy:0.63832
# epochs:3
# min:11 sec:10
# training_loss:0.3133 font_loss:0.03022 char_loss:0.28308 font_accuracy:0.9902 char_accuracy:0.8548
# test_loss:1.73451 font_loss:0.42427 char_loss:1.31024 font_accuracy:0.90546 char_accuracy:0.6469
# epochs:4
# min:11 sec:12
# training_loss:0.30568 font_loss:0.02413 char_loss:0.28155 font_accuracy:0.99189 char_accuracy:0.85813
# test_loss:1.70622 font_loss:0.42273 char_loss:1.2835 font_accuracy:0.90779 char_accuracy:0.64683
# epochs:5
# min:11 sec:18
# training_loss:0.29005 font_loss:0.01728 char_loss:0.27276 font_accuracy:0.99475 char_accuracy:0.85616
# test_loss:1.60722 font_loss:0.41365 char_loss:1.19357 font_accuracy:0.91047 char_accuracy:0.65568
# epochs:6
# min:11 sec:25
# training_loss:0.28355 font_loss:0.01355 char_loss:0.26999 font_accuracy:0.99648 char_accuracy:0.8604
# test_loss:1.82558 font_loss:0.48024 char_loss:1.34534 font_accuracy:0.89859 char_accuracy:0.63643
# epochs:7
# min:11 sec:33
# training_loss:0.30624 font_loss:0.02464 char_loss:0.28159 font_accuracy:0.99103 char_accuracy:0.85619
# test_loss:1.70438 font_loss:0.43524 char_loss:1.26914 font_accuracy:0.90434 char_accuracy:0.64576
# epochs:8
# min:11 sec:36
# training_loss:0.29542 font_loss:0.01815 char_loss:0.27727 font_accuracy:0.99448 char_accuracy:0.85753
# test_loss:1.85307 font_loss:0.50133 char_loss:1.35174 font_accuracy:0.89807 char_accuracy:0.63968
# epochs:9
# min:11 sec:31
# training_loss:0.28341 font_loss:0.01352 char_loss:0.26988 font_accuracy:0.99624 char_accuracy:0.85815
# test_loss:1.74577 font_loss:0.48267 char_loss:1.26309 font_accuracy:0.90595 char_accuracy:0.6472
# epochs:10
# min:11 sec:37
# training_loss:0.28143 font_loss:0.0187 char_loss:0.26273 font_accuracy:0.99435 char_accuracy:0.86192
# test_loss:1.79241 font_loss:0.44406 char_loss:1.34834 font_accuracy:0.91262 char_accuracy:0.64415
# epochs:11
# min:11 sec:41
# training_loss:0.28814 font_loss:0.01766 char_loss:0.27048 font_accuracy:0.99457 char_accuracy:0.85798
# test_loss:1.75071 font_loss:0.4224 char_loss:1.32831 font_accuracy:0.91493 char_accuracy:0.64224
# epochs:12
# min:11 sec:41
# training_loss:0.27304 font_loss:0.01376 char_loss:0.25928 font_accuracy:0.99608 char_accuracy:0.86008
# test_loss:1.83124 font_loss:0.46592 char_loss:1.36533 font_accuracy:0.91225 char_accuracy:0.6473
# epochs:13
# min:11 sec:39
# training_loss:0.26394 font_loss:0.01115 char_loss:0.25279 font_accuracy:0.99691 char_accuracy:0.86103
# test_loss:1.88118 font_loss:0.54464 char_loss:1.33654 font_accuracy:0.89963 char_accuracy:0.64298
# epochs:14
# min:11 sec:38
# training_loss:0.27408 font_loss:0.01741 char_loss:0.25668 font_accuracy:0.99399 char_accuracy:0.86177
# test_loss:1.84157 font_loss:0.45855 char_loss:1.38302 font_accuracy:0.91238 char_accuracy:0.63571
# epochs:15
# min:11 sec:39
# training_loss:0.27006 font_loss:0.01396 char_loss:0.25611 font_accuracy:0.99559 char_accuracy:0.8583
# test_loss:1.87784 font_loss:0.49379 char_loss:1.38405 font_accuracy:0.90176 char_accuracy:0.63931
